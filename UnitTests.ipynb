# %% [markdown]
# # Unit Tests
# Aiming to have test cases for everything in `gnc_prototype_algs`.
# + Author: Luka Bjellos

# %%
# Extensions
import numpy as np

# Functions
import slerp

# %%
# Test case
quaternion_1 = np.array([1,0,0,0])
quaternion_2 = np.array([0.7071,0.7071,0,0])
interp_coef = 0.5

print('Quaternion A:', quaternion_1)
print('Quaternion B:', quaternion_2)
print('Interpolated quaternion with t=', interp_coef, ':', slerp.slerp(quaternion_1, quaternion_2, interp_coef))
# Out:
# Quaternion A: [1 0 0 0]
# Quaternion B: [0.7071 0.7071 0.     0.    ]
# Interpolated quaternion with t= 0.5 : [0.92387953 0.38268343 0.         0.        ]
