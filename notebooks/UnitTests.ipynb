# %% [markdown]
# ## Unit Tests

# %%
# Extensions
import numpy as np

# Functions
# src/python/interpolation/__init__.py
from python.interpolation import slerp

# src/python/transformation/rotationMatrix/__init__.py
from python.transformation.rotationMatrix import rotmat_2_euler

# %%
# Slerp test case
quaternion_1 = np.array([1,0,0,0])
quaternion_2 = np.array([0.7071,0.7071,0,0])
interp_coef = 0.5

print('Quaternion A:', quaternion_1)
print('Quaternion B:', quaternion_2)
print('Interpolated quaternion with t=', interp_coef, ':', slerp(quaternion_1, quaternion_2, interp_coef))
# Out:
# Quaternion A: [1 0 0 0]
# Quaternion B: [0.7071 0.7071 0.     0.    ]
# Interpolated quaternion with t= 0.5 : [0.92387953 0.38268343 0.         0.        ]

# %%
# Rotatation matrix to euler angles test
theta_test = rotmat_2_euler(np.eye(3),"3-1-3")
print(theta_test)
# Out:
# [-0.  0.  0.]
